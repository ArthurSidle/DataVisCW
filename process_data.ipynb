# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import zipfile
import time

# %%
def load_imdb_data(req):
    url = 'https://arthursdata.blob.core.windows.net/datavis/title.{}.tsv.gz'.format(req)
    return pd.read_csv(link, sep='\t', index_col=0, compression='infer')

title_basics = load_imdb_data('basics')
title_episode = load_imdb_data('episodes')
title_ratings = load_imdb_data('ratings')
# Out:
# C:\Users\Arthur\AppData\Local\Temp\ipykernel_7524\2826404596.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(link, sep='\t', index_col=0, compression='infer')

# %%
title_basics.head()
# Out:
#           titleType            primaryTitle           originalTitle isAdult  \
# tconst
# tt0000001     short              Carmencita              Carmencita       0
# tt0000002     short  Le clown et ses chiens  Le clown et ses chiens       0
# tt0000003     short          Pauvre Pierrot          Pauvre Pierrot       0
# tt0000004     short             Un bon bock             Un bon bock       0
# tt0000005     short        Blacksmith Scene        Blacksmith Scene       0
#
#           startYear endYear runtimeMinutes genres
# tconst
# tt0000001      1894      \N              1     \N
# tt0000002      1892      \N              5     \N
# tt0000003      1892      \N              4     \N
# tt0000004      1892      \N             12     \N
# tt0000005      1893      \N              1     \N

# %%
def load_strmsrvc_data(srvc_name):
    with zipfile.ZipFile('https://arthursdata.blob.core.windows.net/datavis/{}.zip'.format(srvc_name)) as f:
        titles_file = f.open('titles.csv')
        credits_file = f.open('credits.csv')
        
        title = pd.read_csv(titles_file, index_col=0)
        credit = pd.read_csv(credits_file, index_col=0)

        titles_file.close()
        credits_file.close()
    
    return {'titles':title, 'credits':credit}

ntfl = load_strmsrvc_data('ntfl')
amzn = load_strmsrvc_data('amzn')
crnc = load_strmsrvc_data('crnc')
dark = load_strmsrvc_data('dark')
dsny = load_strmsrvc_data('dsny')
hbo = load_strmsrvc_data('hbo')
hulu = load_strmsrvc_data('hulu')
prmt = load_strmsrvc_data('prmt')
raku = load_strmsrvc_data('raku')

dsny['titles'].head()
# Out:
#                                    title   type  \
# id
# tm74391                         Fantasia  MOVIE
# tm67803  Snow White and the Seven Dwarfs  MOVIE
# tm82546                        Pinocchio  MOVIE
# tm79357                            Bambi  MOVIE
# tm62671                  Treasure Island  MOVIE
#
#                                                description  release_year  \
# id
# tm74391  Walt Disney's timeless masterpiece is an extra...          1940
# tm67803  A beautiful girl, Snow White, takes refuge in ...          1937
# tm82546  Lonely toymaker Geppetto has his wishes answer...          1940
# tm79357  Bambi's tale unfolds from season to season as ...          1942
# tm62671  Enchanted by the idea of locating treasure bur...          1950
#
#         age_certification  runtime  \
# id
# tm74391                 G      120
# tm67803                 G       83
# tm82546                 G       88
# tm79357                 G       70
# tm62671                PG       96
#
#                                                     genres  \
# id
# tm74391        ['animation', 'family', 'music', 'fantasy']
# tm67803  ['fantasy', 'family', 'romance', 'animation', ...
# tm82546       ['animation', 'comedy', 'family', 'fantasy']
# tm79357                   ['animation', 'drama', 'family']
# tm62671                               ['family', 'action']
#
#         production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# id
# tm74391               ['US']      NaN  tt0032455         7.7     94681.0
# tm67803               ['US']      NaN  tt0029583         7.6    195321.0
# tm82546               ['US']      NaN  tt0032910         7.5    141937.0
# tm79357               ['US']      NaN  tt0034492         7.3    140406.0
# tm62671         ['GB', 'US']      NaN  tt0043067         6.9      8229.0
#
#          tmdb_popularity  tmdb_score
# id
# tm74391           57.751         7.4
# tm67803          107.137         7.1
# tm82546           71.160         7.1
# tm79357           68.136         7.0
# tm62671           10.698         6.5

# %%
title_basics.drop(title_basics[
    (title_basics.titleType == 'short') |
    (title_basics.titleType == 'tvEpisode') |
    (title_basics.titleType == 'tvSpecial') |
    (title_basics.titleType == 'tvShort') |
    (title_basics.titleType == 'videoGame')
].index, inplace=True)

# %%
title_basics.head(10)
# Out:
#           titleType                    primaryTitle  \
# tconst
# tt0000009     movie                      Miss Jerry
# tt0000502     movie                        Bohemios
# tt0000574     movie     The Story of the Kelly Gang
# tt0000591     movie                The Prodigal Son
# tt0000615     movie              Robbery Under Arms
# tt0000630     movie                          Hamlet
# tt0000675     movie                     Don Quijote
# tt0000679     movie  The Fairylogue and Radio-Plays
# tt0000793     movie                   Andreas Hofer
# tt0000814     movie          La bocana de Mar Chica
#
#                             originalTitle isAdult startYear endYear  \
# tconst
# tt0000009                      Miss Jerry       0      1894      \N
# tt0000502                        Bohemios       0      1905      \N
# tt0000574     The Story of the Kelly Gang       0      1906      \N
# tt0000591               L'enfant prodigue       0      1907      \N
# tt0000615              Robbery Under Arms       0      1907      \N
# tt0000630                          Amleto       0      1908      \N
# tt0000675                     Don Quijote       0      1908      \N
# tt0000679  The Fairylogue and Radio-Plays       0      1908      \N
# tt0000793                   Andreas Hofer       0      1909      \N
# tt0000814          La bocana de Mar Chica       0      1909      \N
#
#           runtimeMinutes genres
# tconst
# tt0000009             45     \N
# tt0000502            100     \N
# tt0000574             70     \N
# tt0000591             90     \N
# tt0000615             \N     \N
# tt0000630             \N     \N
# tt0000675             \N     \N
# tt0000679            120     \N
# tt0000793             \N     \N
# tt0000814             \N     \N

# %%
st.write("Here's our first attempt at using data to create a table:")
st.write(pd.DataFrame({
    'first column': [1, 2, 3, 4],
    'second column': [10, 20, 30, 40]
}))
